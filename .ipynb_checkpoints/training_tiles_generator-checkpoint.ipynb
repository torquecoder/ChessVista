# %%
import chess_board_recognizer
import os

#for image_name in os.listdir("training_chessboards"):
chess_board_recognizer.generateTileset("1.png")
# Out:
# Loaded test.png (1920px x 1080px)
# WARNING:tensorflow:From /home/torque/Projects/ChessVista/chess_board_recognizer.py:305: initialize_all_variables (from tensorflow.python.ops.variables) is deprecated and will be removed after 2017-03-02.
# Instructions for updating:
# Use `tf.global_variables_initializer` instead.
# 0 80
# 0 80
# 0 80
# 0 80
# X [ 676  756  836  916  996 1076 1156] [80 80 80 80 80 80]
# Y [273 353 433 513 593 673 753] [80 80 80 80 80 80]
# Chessboard found
# X   (vertical) [ 676  756  836  916  996 1076 1156] [80 80 80 80 80 80]
# Y (horizontal) [273 353 433 513 593 673 753] [80 80 80 80 80 80]
# 7 horizontal and vertical lines found, slicing up squares
# Tiles generated: (80x80)*64
# Order is row-wise from top left of image going right and down, so a8,b8....a7,b7,c7...h1
# Showing 5 random squares...
# #36: E5
# #44: E6
# #46: G6
# #62: G8
# #35: D5
# Created dir training_tiles/squares_test
# #0: saving training_tiles/squares_test/test_A1.png...
# #8: saving training_tiles/squares_test/test_A2.png...
# #16: saving training_tiles/squares_test/test_A3.png...
# #24: saving training_tiles/squares_test/test_A4.png...
# #32: saving training_tiles/squares_test/test_A5.png...
# #40: saving training_tiles/squares_test/test_A6.png...
# #48: saving training_tiles/squares_test/test_A7.png...
# #56: saving training_tiles/squares_test/test_A8.png...
